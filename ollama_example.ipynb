# %% [markdown]
# ## Ollama Python Example

# %% [markdown]
# ### Intro
#
# Ollama is a tool for using LLMs on local environment via API.
# This gives simplicity and flexibility for creating AI/LLM/RAG based applications.
#
#
# ### Setup
# 1. Download and install ollama https://ollama.com/download
# 2. Download Llama 3 8B
#
# `ollama pull llama3:latest`
#
# 3. Download model for embedding
#
# `ollama pull mxbai-embed-large`
#
# 4. Make sure models are downloaded and ollama is running
#
# ```
# ollama list
# NAME                    	ID          	SIZE  	MODIFIED
# mxbai-embed-large:latest	468836162de7	669 MB	7 seconds ago
# llama3:latest           	365c0bd3c000	4.7 GB	17 seconds ago
# ```
#
# `ollama serve`
#
#
# ### Testing API requests to ollama
#
# CURL:
#
# ```
# curl -X POST http://localhost:11434/api/generate -d '{
#   "model": "llama3",
#   "prompt":"Why people don't absorb water directly from air?"
#  }'
# ```
#
# CLI:
#
# ```
# ollama run llama3:latest
# Send a message (/? for help)
# /bye
# ```

# %%
# install Python libraries
# !pip install chromadb==0.5.3
# !pip install ollama
# Out:
# Requirement already satisfied: chromadb==0.5.3 in /home/michal/anaconda3/lib/python3.11/site-packages (0.5.3)
# Requirement already satisfied: build>=1.0.3 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.112.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/michal/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.30.6)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (3.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.19.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.47b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.26.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (7.4.0)
# Requirement already satisfied: importlib-resources in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (6.4.3)
# Requirement already satisfied: grpcio>=1.58.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (1.62.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (3.10.1)
# Requirement already satisfied: httpx>=0.27.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from chromadb==0.5.3) (0.27.0)
# Requirement already satisfied: packaging>=19.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb==0.5.3) (23.2)
# Requirement already satisfied: pyproject_hooks in /home/michal/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb==0.5.3) (1.0.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /home/michal/anaconda3/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb==0.5.3) (0.38.2)
# Requirement already satisfied: anyio in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (4.2.0)
# Requirement already satisfied: certifi in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.0.5)
# Requirement already satisfied: idna in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (3.4)
# Requirement already satisfied: sniffio in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/michal/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.3) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/michal/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.0.7)
# Requirement already satisfied: coloredlogs in /home/michal/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/michal/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (24.3.25)
# Requirement already satisfied: protobuf in /home/michal/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (3.20.3)
# Requirement already satisfied: sympy in /home/michal/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (6.11.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.47b0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.47b0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.47b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.47b0)
# Requirement already satisfied: opentelemetry-util-http==0.47b0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.47b0)
# Requirement already satisfied: setuptools>=16.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/michal/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb==0.5.3) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb==0.5.3) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/michal/anaconda3/lib/python3.11/site-packages (from requests>=2.28->chromadb==0.5.3) (3.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/michal/anaconda3/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb==0.5.3) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==0.5.3) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==0.5.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==0.5.3) (13.3.5)
# Requirement already satisfied: httptools>=0.5.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/michal/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.21.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/michal/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.23.0)
# Requirement already satisfied: websockets>=10.4 in /home/michal/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (13.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/michal/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (4.9)
# Requirement already satisfied: filelock in /home/michal/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (2023.10.0)
# Requirement already satisfied: zipp>=0.5 in /home/michal/anaconda3/lib/python3.11/site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.3) (3.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (2.15.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.3) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/michal/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/michal/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/michal/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.4.8)
# Requirement already satisfied: ollama in /home/michal/anaconda3/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /home/michal/anaconda3/lib/python3.11/site-packages (from ollama) (0.27.0)
# Requirement already satisfied: anyio in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (4.2.0)
# Requirement already satisfied: certifi in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: idna in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.4)
# Requirement already satisfied: sniffio in /home/michal/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/michal/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)

# %% [markdown]
# ### Demo

# %%
# import libraries
import ollama
# vector database
import chromadb
# for reding source documents
import os

# create vector database client
vectorDb = chromadb.Client()

# create collection to store embedded documents
collection = vectorDb.create_collection(name="documents")

# define embedding model
embeddingModel = 'mxbai-embed-large'
# define LLM model
llmModel = 'llama3'

# source documents folder Path 
path = "data/cryptocurrency_wikipedia"

# iterate through all file 
for i,file in enumerate(os.listdir(path)):
    # check for .txt extension
    if file.endswith(".txt"):
        file_path = f"{path}/{file}"
        with open(file_path, 'r') as f:
            # get file content
            document = f.read()
            # get embedding for document
            response = ollama.embeddings(model=embeddingModel, prompt=document)
            embedding = response["embedding"]
            # load document to vector database
            collection.add(
                ids=[str(i)],
                embeddings=[embedding],
                documents=[document]
            )

# define the prompt
prompt = 'is Coinye the name of an animal?'

# create embeddings for the prompt
response = ollama.embeddings(
    prompt=prompt,
    model=embeddingModel
)

# Query the collection for the most similar document
results = collection.query(
    query_embeddings=[response["embedding"]],
    n_results=1
)

# get best matching document
data = results['documents'][0][0]

# generate a response using the LLM
output = ollama.generate(
    model=llmModel,
    prompt=f"Using this data: {data}. Respond to this prompt: {prompt}"
)

# print result
print(output['response'])
# Out:
# According to the Wikipedia article, Coinye is actually a cryptocurrency, but at one point, its mascot was a "half-man-half-fish hybrid" (likely a reference to a South Park episode where Kanye West is called a "gay fish"). So, while Coinye isn't directly an animal name, it has some aquatic creature connotations!
